# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Donrep/ASFLYRANK/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# Ranking Signals Analysis

# Your code for cell 3 will go here

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
#Lane: Ranking Signal Analysis
#Why: Search ranking drives 80% of traffic for FlyRank clients. Understanding which signals like backlinks, content depth, page speed, CTR actually move rankings helps us prioritize SEO work and beat competitors. The impact of this lane is direct on the business with lots of measurable data.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import numpy as np

# Create demo data since starter CSV is "coming soon"
np.random.seed(42)
df = pd.DataFrame({
    'current_rank': np.random.randint(1, 50, 100),
    'backlinks': np.random.randint(10, 5000, 100),
    'page_speed': np.random.uniform(0.5, 5.0, 100),
    'content_length': np.random.randint(300, 3000, 100),
    'ctr': np.random.uniform(0.01, 0.2, 100)
})

print("Demo data - First 5 rows:")
print(df.head())

print("\nCorrelation with rank:")
print(df[['current_rank', 'backlinks', 'page_speed', 'content_length', 'ctr']].corr()['current_rank'].sort_values())
# Out:
# Demo data - First 5 rows:
#    current_rank  backlinks  page_speed  content_length       ctr
# 0            39       2037    4.173943            2837  0.042908
# 1            29       2705    4.092553            1709  0.092432
# 2            15       1505    1.178229            1084  0.085716
# 3            43        401    2.786894             545  0.127012
# 4             8       4524    3.631158            1800  0.130668
#
# Correlation with rank:
# ctr              -0.191517
# content_length   -0.049294
# page_speed       -0.021977
# backlinks         0.029306
# current_rank      1.000000
# Name: current_rank, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# Cell 4: Careful Words

print("Key limitation: Correlation is not causation")
print("We cannot claim that backlinks or CTR directly cause better rankings.")
print("There may be confounding factors like domain authority, brand, or Google updates.")
print("Next step: Run A/B tests or controlled experiments to validate if changing these signals actually moves rank.")

# Careful interpretation:
# 1. The correlations we see only show association, not proof that changing backlinks will improve rank.
# 2. Other variables we do not have in this dataset could explain both rank and the signal.
# 3. Before spending 7 weeks building here, we should test 1 signal with real experiments to confirm impact.
#
# Decision: Proceed with Ranking Signal Analysis lane, but treat findings as hypotheses to test, not facts.
# Out:
# Key limitation: Correlation is not causation
# We cannot claim that backlinks or CTR directly cause better rankings.
# There may be confounding factors like domain authority, brand, or Google updates.
# Next step: Run A/B tests or controlled experiments to validate if changing these signals actually moves rank.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
